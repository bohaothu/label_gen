# %%
import numpy as np
import pandas as pd
import os
import pickle

# %%
dataset_directory=os.path.join("..","api","dataset")

# %%
with open(os.path.join(dataset_directory, "birds",'train.pickle'), 'rb') as f:
    X_train, y_train, feature_names, label_names = pickle.load(f)

# %%
len(feature_names)
# Out:
# 260

# %%
with open(os.path.join(dataset_directory, "delicious",'train.pickle'), 'rb') as f:
    X_train, y_train, feature_names, label_names = pickle.load(f)

# %%
feature_names
# Out:
# [('_qacct', ['0', '1']),
#  ('accessing', ['0', '1']),
#  ('actionscript', ['0', '1']),
#  ('activerecord', ['0', '1']),
#  ('addoverlay', ['0', '1']),
#  ('afternoon', ['0', '1']),
#  ('against', ['0', '1']),
#  ('air', ['0', '1']),
#  ('ajax_action', ['0', '1']),
#  ('als', ['0', '1']),
#  ('angry', ['0', '1']),
#  ('anyway', ['0', '1']),
#  ('apache', ['0', '1']),
#  ('approved', ['0', '1']),
#  ('arm', ['0', '1']),
#  ('arms', ['0', '1']),
#  ('article', ['0', '1']),
#  ('asleep', ['0', '1']),
#  ('ass', ['0', '1']),
#  ('atlantis', ['0', '1']),
#  ('auch', ['0', '1']),
#  ('auf', ['0', '1']),
#  ('aus', ['0', '1']),
#  ('awake', ['0', '1']),
#  ('awkward', ['0', '1']),
#  ('baking', ['0', '1']),
#  ('barely', ['0', '1']),
#  ('bathroom', ['0', '1']),
#  ('beckett', ['0', '1']),
#  ('bed', ['0', '1']),
#  ('bei', ['0', '1']),
#  ('belly', ['0', '1']),
#  ('beneath', ['0', '1']),
#  ('bent', ['0', '1']),
#  ('ber', ['0', '1']),
#  ('beside', ['0', '1']),
#  ('bitch', ['0', '1']),
# ...

# %%
with open(os.path.join(dataset_directory, "bibtex",'train.pickle'), 'rb') as f:
    X_train, y_train, feature_names, label_names = pickle.load(f)

# %%
feature_names
# Out:
# [('0', ['0', '1']),
#  ('000', ['0', '1']),
#  ('02', ['0', '1']),
#  ('05', ['0', '1']),
#  ('06', ['0', '1']),
#  ('1', ['0', '1']),
#  ('10', ['0', '1']),
#  ('100', ['0', '1']),
#  ('11', ['0', '1']),
#  ('12', ['0', '1']),
#  ('13', ['0', '1']),
#  ('14', ['0', '1']),
#  ('15', ['0', '1']),
#  ('16', ['0', '1']),
#  ('17', ['0', '1']),
#  ('18', ['0', '1']),
#  ('1997', ['0', '1']),
#  ('1998', ['0', '1']),
#  ('1999', ['0', '1']),
#  ('2', ['0', '1']),
#  ('20', ['0', '1']),
#  ('2000', ['0', '1']),
#  ('2001', ['0', '1']),
#  ('2002', ['0', '1']),
#  ('2003', ['0', '1']),
#  ('2004', ['0', '1']),
#  ('2005', ['0', '1']),
#  ('2006', ['0', '1']),
#  ('2007', ['0', '1']),
#  ('24', ['0', '1']),
#  ('25', ['0', '1']),
#  ('3', ['0', '1']),
#  ('30', ['0', '1']),
#  ('4', ['0', '1']),
#  ('40', ['0', '1']),
#  ('5', ['0', '1']),
#  ('50', ['0', '1']),
#  ('6', ['0', '1']),
#  ('60', ['0', '1']),
#  ('7', ['0', '1']),
#  ('8', ['0', '1']),
#  ('9', ['0', '1']),
# ...

# %%
with open(os.path.join(dataset_directory, "emotions",'train.pickle'), 'rb') as f:
    X_train, y_train, feature_names, label_names = pickle.load(f)
# Out:
# ('Mean_Acc1298_Mean_Mem40_Centroid', 'NUMERIC')

# %%
feature_names
# Out:
# [('Mean_Acc1298_Mean_Mem40_Centroid', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_Rolloff', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_Flux', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_0', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_1', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_2', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_3', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_4', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_5', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_6', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_7', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_8', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_9', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_10', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_11', 'NUMERIC'),
#  ('Mean_Acc1298_Mean_Mem40_MFCC_12', 'NUMERIC'),
#  ('Mean_Acc1298_Std_Mem40_Centroid', 'NUMERIC'),
#  ('Mean_Acc1298_Std_Mem40_Rolloff', 'NUMERIC'),
#  ('Mean_Acc1298_Std_Mem40_Flux', 'NUMERIC'),
# ...

# %%
with open(os.path.join(dataset_directory, "genbase",'train.pickle'), 'rb') as f:
    X_train, y_train, feature_names, label_names = pickle.load(f)

# %%
feature_names
# Out:
# [('protein',
#   ['O00060',
#    'O00139',
#    'O02741',
#    'O08424',
#    'O12984',
#    'O12988',
#    'O13224',
#    'O13351',
#    'O13433',
#    'O14343',
#    'O14558',
#    'O14782',
#    'O14788',
#    'O14936',
#    'O15066',
#    'O15886',
#    'O19131',
#    'O23826',
#    'O24585',
#    'O24594',
#    'O26662',
#    'O28538',
#    'O30851',
#    'O31288',
#    'O34328',
#    'O35066',
#    'O35071',
#    'O35235',
#    'O35734',
#    'O35787',
#    'O35878',
#    'O43093',
#    'O43416',
#    'O43557',
#    'O43896',
#    'O49886',
#    'O49939',
#    'O51628',
#    'O53021',
#    'O55165',
#    'O59469',
#    'O60282',
#    'O60333',
#    'O62683',
#    'O64966',
#    'O64967',
#    'O66105',
#    'O69241',
#    'O69242',
#    'O70589',
#    'O73919',
#    'O74164',
#    'O75001',
#    'O75888',
#    'O76819',
#    'O77510',
#    'O77736',
#    'O77764',
#    'O84033',
#    'O86110',
#    'O88658',
#    'O93591',
#    'O95049',
#    'O95235',
#    'O95239',
# ...

# %%
df=pd.DataFrame.sparse.from_spmatrix(X_train)
df.columns=list(map(lambda x: x[0], feature_names))

# %%
df["location"].value_counts()
# Out:
# 6.0     39
# 7.0     35
# 2.0     34
# 8.0     34
# 11.0    29
# 3.0     29
# 1.0     28
# 4.0     27
# 5.0     20
# 0.0     19
# 10.0    15
# 9.0     13
# Name: location, dtype: int64

# %%
type(df["location"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df["location"].value_counts().to_json(orient="columns")
# Out:
# '{"6.0":39,"7.0":35,"2.0":34,"8.0":34,"11.0":29,"3.0":29,"1.0":28,"4.0":27,"5.0":20,"0.0":19,"10.0":15,"9.0":13}'
